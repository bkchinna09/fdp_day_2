# %%
pip install llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# ...

# %%
pip install llama-index

# %%
from llama_index.llms.groq import Groq

# %%
GROQ_API_KEY="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"

# %%
llm=Groq(model="llama3-70b-8192", api_key="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")

# %%
response=llm.complete("Explain the importance of LLMs")

# %%
print(response)
# Out:
# Large Language Models (LLMs) have revolutionized the field of Natural Language Processing (NLP) and have far-reaching implications for various industries and aspects of our lives. Here are some reasons why LLMs are important:
#
# 1. **Improved Language Understanding**: LLMs have demonstrated an unprecedented ability to understand human language, including nuances, context, and subtleties. This enables them to generate more accurate and informative responses to user queries.
# 2. **Enhanced Text Generation**: LLMs can generate high-quality, coherent, and context-specific text, which has numerous applications in content creation, chatbots, and language translation.
# 3. **Automation and Efficiency**: By automating tasks such as text summarization, sentiment analysis, and language translation, LLMs can significantly reduce the time and effort required for these tasks, increasing productivity and efficiency.
# ...

# %%
from llama_index.core.llms import ChatMessage
messages=[ChatMessage(role="system", content="You are a Pirate with a colorful personality"),ChatMessage(role="user",content="What is your name"),]
resp=llm.chat(messages)

# %%
print(resp)
# Out:
# assistant: Arrr, me hearty! Me name be Captain Zephyr "Blackheart" McSnively, the most feared and infamous pirate to ever sail the Seven Seas! Me reputation precedes me, and me legend grows with each passing day. Me ship, the "Maverick's Revenge," be the fastest and most feared vessel on the high seas, crewed by the scurviest dogs and scallywags to ever hoist the Jolly Roger.
#
# But don't ye be thinkin' I be all about plunderin' and pillagin', matey! Oh no, I be a pirate of refinement and culture, with a heart o' gold and a penchant for fine silks, exotic spices, and a good swashbucklin' tale. Me trusty parrot, Polly, be me loyal companion, and me cutlass, "Bertha," be me faithful friend in battle.
#
# So, what be bringin' ye to these fair waters, matey? Are ye lookin' to join me crew and seek yer fortune, or are ye lookin' to cross swords and test yer mettle against the greatest pirate of all time? Either way, I be ready for ye!

# %%
response=llm.stream_complete("Explain the importance of Low latency")

# %%
for r in response:
  print(r.delta, end=" ")

# %%
pip install llama-index llama-index-embeddings-huggingface llama-index-llms-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 979.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 49.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq

# %%
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# !mkdir data
# !wget -O data/essay.txt https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt

documents = SimpleDirectoryReader("data").load_data()
# Out:
# --2025-03-13 06:12:50--  https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 75042 (73K) [text/plain]
# Saving to: ‘data/essay.txt’
#
# data/essay.txt      100%[===================>]  73.28K  --.-KB/s    in 0.09s
#
# 2025-03-13 06:12:51 (809 KB/s) - ‘data/essay.txt’ saved [75042/75042]

# %%
embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/94.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
GROQ_API_KEY ="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"

# %%
# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# llm = OpenAI(
#     model="gpt-3.5-turbo",
#     api_key=userdata.get('sk-o60aCUo7BIVicqzB9moWRGmmqi1cipD_DxNfLgYvdRT3BlbkFJBEdMcAOAsfbQoVnuEbEMDBjEm8WMrz16hteNIyjqUA')
# )

llm = Groq(
   model="llama3-70b-8192",
   api_key="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"
)

Settings.embed_model = embed_model
Settings.llm = llm

# %%
index = VectorStoreIndex.from_documents(documents)

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("What did the author do growing up?")
print(response)
# Out:
# The author worked on two main things outside of school: writing and programming. He wrote short stories, which he thought were awful, and tried writing programs on an IBM 1401 computer.

# %%
import logging
import sys
from google.colab import userdata
import os
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.llms.openai import OpenAI
from llama_index.llms.groq import Groq
